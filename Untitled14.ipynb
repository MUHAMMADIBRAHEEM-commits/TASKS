# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHAMMADIBRAHEEM-commits/TASKS/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
loan_data = pd.read_csv("/content/train_u6lujuX_CVtuZ9i.csv")

# %%
loan_data.head
# Out:
# <bound method NDFrame.head of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data.shape
# Out:
# (614, 13)

# %%
loan_data.tail
# Out:
# <bound method NDFrame.tail of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data.tail(2)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
loan_data.head (20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
loan_data.head(100)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# ..       ...     ...     ...        ...           ...           ...
# 95  LP001326    Male      No          0      Graduate           NaN
# 96  LP001327  Female     Yes          0      Graduate            No
# 97  LP001333    Male     Yes          0      Graduate            No
# 98  LP001334    Male     Yes          0  Not Graduate            No
# 99  LP001343    Male     Yes          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# ...

# %%
sns.histplot(loan_data["LoanAmount"], kde=True)
plt.title("Distribution of LoanAmount")
# Out:
# Text(0.5, 1.0, 'Distribution of LoanAmount')

# %%
sns.histplot(loan_data["Education"], kde=True)
plt.title("Distribution of Education")
# Out:
# Text(0.5, 1.0, 'Distribution of Education')

# %%
sns.histplot(loan_data["ApplicantIncome"], kde=True)
plt.title("Distribution of ApplicantIncome")
# Out:
# Text(0.5, 1.0, 'Distribution of ApplicantIncome')

# %%
sns.scatterplot(x=loan_data["LoanAmount"], y=loan_data["Education"])
plt.title("Scatter plot: LoanAmount vs Education")
plt.xlabel("LoanAmount")
plt.ylabel("Education")
plt.show()

# %%
sns.scatterplot(x=loan_data["LoanAmount"], y=loan_data["ApplicantIncome"])
plt.title("Scatter plot: LoanAmount vs ApplicantIncome")
plt.xlabel("LoanAmount")
plt.ylabel("ApplicantIncome")
plt.show()

# %%
sns.scatterplot(x=loan_data["Education"], y=loan_data["ApplicantIncome"])
plt.title("Scatter plot: Education vs ApplicantIncome")
plt.xlabel("LoanAmount")
plt.ylabel("Education")
plt.show()

# %%
loan_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Dropping the missing values to obtain good results
loan_data = loan_data.dropna()

# %%
loan_data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# replacing the value of 3+ to 4
loan_data = loan_data.replace(to_replace='3+', value=4)

# %%
# dependent values
loan_data['Dependents'].value_counts()
# Out:
# Dependents
# 0    274
# 2     85
# 1     80
# 4     41
# Name: count, dtype: int64

# %%
# separating the data and label
X = loan_data.drop(columns=['Loan_ID','Loan_Status'],axis=1)
Y = loan_data['Loan_Status']

# convert categorical columns to numerical values
X.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},
                      'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},'Education':{'Graduate':1,'Not Graduate':0}},inplace=True)
# Out:
# /tmp/ipython-input-82-3391290818.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},

# %%
print(X)
print(Y)
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# 5         1        1          2          1              1             5417
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          4          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %%
# convert categorical columns to numerical values
loan_data.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},
                      'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},'Education':{'Graduate':1,'Not Graduate':0}},inplace=True)
# Out:
# /tmp/ipython-input-84-798390125.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   loan_data.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},

# %%
loan_data.head(5)
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 1             1.0              0           N
# 2             1.0              2           Y
# ...

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (480, 11) (432, 11) (48, 11)

# %%
model = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=42)
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
# Evaluate the model
Y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(Y_test, Y_pred))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.7708333333333334
# Confusion Matrix:
#  [[ 6  9]
#  [ 2 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.75      0.40      0.52        15
#            Y       0.78      0.94      0.85        33
#
#     accuracy                           0.77        48
#    macro avg       0.76      0.67      0.69        48
# weighted avg       0.77      0.77      0.75        48
